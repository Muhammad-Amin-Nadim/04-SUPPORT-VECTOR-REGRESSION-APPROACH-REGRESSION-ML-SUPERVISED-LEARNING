# %% [markdown]
# ## MUHAMMAD AMIN NADIM
# https://muhammad-amin-nadim.github.io/

# %% [markdown]
# ## Support Vector Regression Approach (Delay in AIDS Reporting in England and Wales prediction)

# %% [markdown]
# #### Part 1: Data Preprocessing

# %%
# import Libraries
import pandas as pd                      # used for import the dataset
import numpy as np                       # used for multidimensional array
import matplotlib.pyplot as plt          # used for plot the Graph

# %%
#import the dataset
dataset = pd.read_csv("aids.csv")
X = dataset.iloc[:,:-1].values       # predictor attribute 
y = dataset.iloc[:,-1].values        # target attribute

# %%
# split the dataset into test set and train set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %% [markdown]
# #### Part 2: Building the Model

# %%
# import SVM regression model from sscikit learn
from sklearn.svm import SVR

# %%
# init the model
regressor = SVR(kernel = 'rbf')

# %%
# fit the training model into our SVM classifer regression model
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# #### Part 3: Making a prediction and visualize the result

# %%
# making a prediction
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([11.69915336,  6.60457215,  0.05483869, 16.46948455,  0.28605342,
#         1.6841949 ,  3.80380195,  4.07448043, 18.04343983,  4.37252937,
#        -0.14001389,  0.27549256,  2.29197729,  0.63626364,  6.29101241,
#         8.7961413 , 11.65620565,  4.83068551,  0.60079902, 14.36013389,
#         3.4462489 ,  2.058794  , 15.13863616,  1.1565096 , 13.34208924,
#         1.25527677,  8.39348532,  0.72517149, 18.84065874,  1.16283843,
#        -0.32966022,  2.33976855, -0.09290726,  2.32211353,  1.38686701,
#         2.06265099,  1.06782064,  0.52567981, 18.63433996, 16.84724664,
#        12.63349272,  0.27022336, -0.29152554,  2.23903533,  3.34313009,
#         3.67224398,  0.80595284,  1.01511219, 18.30677871,  3.21464577,
#         0.12102263, 14.67039571, 19.56545158, 20.93557557, 18.95509313,
#         0.91207884, 20.8697832 , -0.24140187, 19.9185664 ,  0.37666105,
#        12.05132294,  5.49186421,  0.33017334,  0.71573041, 12.09734106,
# ...

# %%
# Visualising the Regression results
plt.scatter(y_test, y_pred, color = 'red')
plt.plot(y_test, regressor.predict(X_test), color = 'blue')
plt.title('Delay in AIDS Reporting in England and Wales')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
